# %%
from pathlib import Path    

def list_csv_files(directory: str) -> list:
    """List all Python files in the given directory."""
    p = Path(directory)
    return [str(file) for file in p.glob('*.py')]

listed_files = list_csv_files ('../ datos')

# %%
print (listed_files)
# Out:
# []

# %%
Path_1=Path('..')/'datos'

listed_files = list(Path_1.glob('*.csv'))

print(listed_files)
# Out:
# [PosixPath('../datos/productos.csv')]

# %%
archivo1=Path('../datos/productos.csv')
            
print(archivo1.exists())
# Out:
# True

# %%
print(archivo1.stat())

print(archivo1.stem)
print(archivo1.suffix)
print(archivo1.parent)
# Out:
# os.stat_result(st_mode=33279, st_ino=10696049115697740, st_dev=67, st_nlink=1, st_uid=0, st_gid=0, st_size=90, st_atime=1766547699, st_mtime=1766106873, st_ctime=1766106873)
# productos
# .csv
# ../datos

# %%
archivo2=Path('../docker-compose.yml')

print(archivo2.exists())
# Out:
# True

# %%
print(archivo2.stat())

print(archivo2.stem)
print(archivo2.suffix)
print(archivo2.parent)
# Out:
# os.stat_result(st_mode=33279, st_ino=5629499534293803, st_dev=67, st_nlink=1, st_uid=0, st_gid=0, st_size=1019, st_atime=1766547078, st_mtime=1766544717, st_ctime=1766544717)
# docker-compose
# .yml
# ..

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

logging.info("Proceso iniciado")
archivo1=Path('../datos/productos.csv')
if archivo1.exists():
    logging.info(f"El archivo {archivo1} existe.")
    logging.info(f"Tamaño del archivo: {archivo1.stat().st_size} bytes")
    logging.info(f"Nombre del archivo sin extensión: {archivo1.stem}")
    logging.info(f"Extensión del archivo: {archivo1.suffix}")
    logging.info(f"Directorio padre: {archivo1.parent}")
else:
    logging.warning(f"El archivo {archivo1} no existe.")
    logging.error("No se pueden obtener detalles del archivo inexistente.")
# Out:
# 2025-12-24 03:43:46,987 - INFO - Proceso iniciado
# 2025-12-24 03:43:46,992 - INFO - El archivo ../datos/productos.csv existe.
# 2025-12-24 03:43:46,996 - INFO - Tamaño del archivo: 90 bytes
# 2025-12-24 03:43:46,997 - INFO - Nombre del archivo sin extensión: productos
# 2025-12-24 03:43:46,999 - INFO - Extensión del archivo: .csv
# 2025-12-24 03:43:46,999 - INFO - Directorio padre: ../datos

# %%
import numpy as np
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

lista_elegibles= [1,2,3,0,0,"0","o","o","o","o"]

logging.info(f"Lista de elegibles: {lista_elegibles}")

## Escogemos dos


elegibles_1 = np.random.choice(lista_elegibles, size=2, replace=False)
logging.info(f"Elegibles 1: {elegibles_1}")

try:
    primer_elemento = int(elegibles_1[0])
    logging.info(f"Primer elemento seleccionado: {primer_elemento}")
    segundo_elemento = int(elegibles_1[1])
    logging.info(f"Segundo elemento seleccionado: {segundo_elemento}")
    
    div= primer_elemento / segundo_elemento
    logging.info(f"Resultado de la división: {div}")
except ZeroDivisionError:
    logging.error("Error: División por cero no permitida.")
except Exception as e:
    logging.error(f"Ocurrió un error inesperado: {e}")
# Out:
# 2025-12-24 03:43:55,392 - INFO - Lista de elegibles: [1, 2, 3, 0, 0, '0', 'o', 'o', 'o', 'o']
# 2025-12-24 03:43:55,410 - INFO - Elegibles 1: ['0' 'o']
# 2025-12-24 03:43:55,412 - INFO - Primer elemento seleccionado: 0
# 2025-12-24 03:43:55,413 - ERROR - Ocurrió un error inesperado: invalid literal for int() with base 10: np.str_('o')

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
